# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | kodinsk
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | iisalmi
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | chuy
# Processing Record 8 of Set 1 | sabang
# Processing Record 9 of Set 1 | sorong
# Processing Record 10 of Set 1 | lingao
# Processing Record 11 of Set 1 | san patricio
# Processing Record 12 of Set 1 | brokopondo
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | erode
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 1 | torbay
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | nur
# Processing Record 20 of Set 1 | kruisfontein
# Processing Record 21 of Set 1 | tumut
# Processing Record 22 of Set 1 | irkutsk
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | pevek
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | kabompo
# Processing Record 27 of Set 1 | galesong
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | san cristobal
# Processing Record 31 of Set 1 | cidreira
# Processing Record 32 of Set 1 | bac can
# City not found. Skipping...
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | ankazobe
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | keetmanshoop
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | cabo san lucas
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | salalah
# Processing Record 43 of Set 1 | victoria
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | dunedin
# Processing Record 47 of Set 1 | buraydah
# Processing Record 48 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 1 | sisimiut
# Processing Record 50 of Set 1 | sonoita
# Processing Record 1 of Set 2 | troitsko-pechorsk
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | sao joao da barra
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | kandalaksha
# Processing Record 6 of Set 2 | dingle
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | itarema
# Processing Record 9 of Set 2 | jalu
# Processing Record 10 of Set 2 | goderich
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | vakhrushev
# Processing Record 13 of Set 2 | plerin
# Processing Record 14 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 2 | ilulissat
# Processing Record 16 of Set 2 | puerto escondido
# Processing Record 17 of Set 2 | davila
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | kavaratti
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 2 | alta floresta
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | padang
# Processing Record 29 of Set 2 | constitucion
# Processing Record 30 of Set 2 | rikitea
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | punta arenas
# Processing Record 34 of Set 2 | faanui
# Processing Record 35 of Set 2 | san matias
# Processing Record 36 of Set 2 | richards bay
# Processing Record 37 of Set 2 | katherine
# Processing Record 38 of Set 2 | iqaluit
# Processing Record 39 of Set 2 | mount gambier
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | alekseyevsk
# Processing Record 42 of Set 2 | elliot lake
# Processing Record 43 of Set 2 | tura
# Processing Record 44 of Set 2 | general roca
# Processing Record 45 of Set 2 | vanimo
# Processing Record 46 of Set 2 | saint george
# Processing Record 47 of Set 2 | kahului
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | bolivar
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | karpathos
# Processing Record 2 of Set 3 | albany
# Processing Record 3 of Set 3 | pemba
# Processing Record 4 of Set 3 | havre-saint-pierre
# Processing Record 5 of Set 3 | chokurdakh
# Processing Record 6 of Set 3 | pangoa
# Processing Record 7 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 8 of Set 3 | butaritari
# Processing Record 9 of Set 3 | leamington
# Processing Record 10 of Set 3 | alofi
# Processing Record 11 of Set 3 | tiznit
# Processing Record 12 of Set 3 | gajendragarh
# Processing Record 13 of Set 3 | lasa
# Processing Record 14 of Set 3 | jamestown
# Processing Record 15 of Set 3 | severo-kurilsk
# Processing Record 16 of Set 3 | kaeo
# Processing Record 17 of Set 3 | ventspils
# Processing Record 18 of Set 3 | haines junction
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | la ciotat
# Processing Record 21 of Set 3 | bredasdorp
# Processing Record 22 of Set 3 | ulladulla
# Processing Record 23 of Set 3 | paragominas
# Processing Record 24 of Set 3 | purranque
# Processing Record 25 of Set 3 | urumqi
# Processing Record 26 of Set 3 | saurimo
# Processing Record 27 of Set 3 | mar del plata
# Processing Record 28 of Set 3 | beringovskiy
# Processing Record 29 of Set 3 | debar
# Processing Record 30 of Set 3 | astana
# Processing Record 31 of Set 3 | san juan
# Processing Record 32 of Set 3 | novo oriente
# Processing Record 33 of Set 3 | lashio
# Processing Record 34 of Set 3 | abha
# Processing Record 35 of Set 3 | mareeba
# Processing Record 36 of Set 3 | kuvandyk
# Processing Record 37 of Set 3 | zhigansk
# Processing Record 38 of Set 3 | aksarka
# Processing Record 39 of Set 3 | fairbanks
# Processing Record 40 of Set 3 | cheyenne
# Processing Record 41 of Set 3 | jian
# Processing Record 42 of Set 3 | upernavik
# Processing Record 43 of Set 3 | frome
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 46 of Set 3 | ahipara
# Processing Record 47 of Set 3 | tucumcari
# Processing Record 48 of Set 3 | keti bandar
# Processing Record 49 of Set 3 | vidim
# Processing Record 50 of Set 3 | the pas
# Processing Record 1 of Set 4 | norman wells
# Processing Record 2 of Set 4 | vostok
# Processing Record 3 of Set 4 | bethel
# Processing Record 4 of Set 4 | ixtapa
# Processing Record 5 of Set 4 | luwuk
# Processing Record 6 of Set 4 | bonthe
# Processing Record 7 of Set 4 | lazaro cardenas
# Processing Record 8 of Set 4 | rockport
# Processing Record 9 of Set 4 | inhambane
# Processing Record 10 of Set 4 | tuatapere
# Processing Record 11 of Set 4 | yeppoon
# Processing Record 12 of Set 4 | sirjan
# Processing Record 13 of Set 4 | linxia
# Processing Record 14 of Set 4 | saldanha
# Processing Record 15 of Set 4 | sitka
# Processing Record 16 of Set 4 | nacala
# Processing Record 17 of Set 4 | eureka
# Processing Record 18 of Set 4 | port lincoln
# Processing Record 19 of Set 4 | filadelfia
# Processing Record 20 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 21 of Set 4 | berlevag
# Processing Record 22 of Set 4 | lompoc
# Processing Record 23 of Set 4 | pisco
# Processing Record 24 of Set 4 | half moon bay
# Processing Record 25 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 4 | olafsvik
# Processing Record 29 of Set 4 | solnechnyy
# Processing Record 30 of Set 4 | avarua
# Processing Record 31 of Set 4 | ancud
# Processing Record 32 of Set 4 | christchurch
# Processing Record 33 of Set 4 | nola
# Processing Record 34 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 4 | sacaseni
# Processing Record 36 of Set 4 | jurm
# Processing Record 37 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 4 | bakersfield
# Processing Record 40 of Set 4 | katsuura
# Processing Record 41 of Set 4 | rovaniemi
# Processing Record 42 of Set 4 | jacareacanga
# Processing Record 43 of Set 4 | nanortalik
# Processing Record 44 of Set 4 | sydney
# Processing Record 45 of Set 4 | oktyabrskiy
# Processing Record 46 of Set 4 | novoagansk
# Processing Record 47 of Set 4 | kapuskasing
# Processing Record 48 of Set 4 | boden
# Processing Record 49 of Set 4 | souillac
# Processing Record 50 of Set 4 | aransas pass
# Processing Record 1 of Set 5 | hurricane
# Processing Record 2 of Set 5 | tasiilaq
# Processing Record 3 of Set 5 | xining
# Processing Record 4 of Set 5 | hamilton
# Processing Record 5 of Set 5 | kaniama
# Processing Record 6 of Set 5 | klaksvik
# Processing Record 7 of Set 5 | tuscaloosa
# Processing Record 8 of Set 5 | hami
# Processing Record 9 of Set 5 | leningradskiy
# Processing Record 10 of Set 5 | los llanos de aridane
# Processing Record 11 of Set 5 | vryheid
# Processing Record 12 of Set 5 | constantine
# Processing Record 13 of Set 5 | zapolyarnyy
# Processing Record 14 of Set 5 | talara
# Processing Record 15 of Set 5 | mantua
# Processing Record 16 of Set 5 | placerville
# Processing Record 17 of Set 5 | mugango
# Processing Record 18 of Set 5 | qaqortoq
# Processing Record 19 of Set 5 | yellowknife
# Processing Record 20 of Set 5 | kampong chhnang
# Processing Record 21 of Set 5 | nome
# Processing Record 22 of Set 5 | voh
# Processing Record 23 of Set 5 | kabanjahe
# Processing Record 24 of Set 5 | lorengau
# Processing Record 25 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 5 | diamantino
# Processing Record 27 of Set 5 | luderitz
# Processing Record 28 of Set 5 | broome
# Processing Record 29 of Set 5 | grand gaube
# Processing Record 30 of Set 5 | dikson
# Processing Record 31 of Set 5 | port hardy
# Processing Record 32 of Set 5 | zykovo
# Processing Record 33 of Set 5 | tecoanapa
# Processing Record 34 of Set 5 | barcelos
# Processing Record 35 of Set 5 | angoche
# Processing Record 36 of Set 5 | dunkwa
# Processing Record 37 of Set 5 | puerto carreno
# Processing Record 38 of Set 5 | huarmey
# Processing Record 39 of Set 5 | mazamet
# Processing Record 40 of Set 5 | najran
# Processing Record 41 of Set 5 | muyezerskiy
# Processing Record 42 of Set 5 | baruun-urt
# Processing Record 43 of Set 5 | san policarpo
# Processing Record 44 of Set 5 | sao raimundo das mangabeiras
# Processing Record 45 of Set 5 | coquimbo
# Processing Record 46 of Set 5 | saint-augustin
# Processing Record 47 of Set 5 | innisfail
# Processing Record 48 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 5 | yulara
# Processing Record 50 of Set 5 | caravelas
# Processing Record 1 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 6 | montgomery
# Processing Record 3 of Set 6 | lochgilphead
# Processing Record 4 of Set 6 | portland
# Processing Record 5 of Set 6 | russell
# Processing Record 6 of Set 6 | airai
# Processing Record 7 of Set 6 | burnie
# Processing Record 8 of Set 6 | champerico
# Processing Record 9 of Set 6 | anloga
# Processing Record 10 of Set 6 | havoysund
# Processing Record 11 of Set 6 | kendari
# Processing Record 12 of Set 6 | talnakh
# Processing Record 13 of Set 6 | clonakilty
# Processing Record 14 of Set 6 | pasaco
# Processing Record 15 of Set 6 | yumen
# Processing Record 16 of Set 6 | saint-pierre
# Processing Record 17 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 6 | jubasan
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | sobolevo
# Processing Record 21 of Set 6 | birobidzhan
# Processing Record 22 of Set 6 | rio gallegos
# Processing Record 23 of Set 6 | atbasar
# Processing Record 24 of Set 6 | palm harbor
# Processing Record 25 of Set 6 | navalmoral de la mata
# Processing Record 26 of Set 6 | bulle
# Processing Record 27 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 6 | touros
# Processing Record 29 of Set 6 | mayya
# Processing Record 30 of Set 6 | japura
# Processing Record 31 of Set 6 | baiersbronn
# Processing Record 32 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 6 | unecha
# Processing Record 34 of Set 6 | ardakan
# Processing Record 35 of Set 6 | yaqui
# Processing Record 36 of Set 6 | dunn
# Processing Record 37 of Set 6 | sept-iles
# Processing Record 38 of Set 6 | san borja
# Processing Record 39 of Set 6 | mezen
# Processing Record 40 of Set 6 | pinawa
# Processing Record 41 of Set 6 | naantali
# Processing Record 42 of Set 6 | skiros
# City not found. Skipping...
# Processing Record 43 of Set 6 | nemuro
# Processing Record 44 of Set 6 | fare
# Processing Record 45 of Set 6 | rawson
# Processing Record 46 of Set 6 | provideniya
# Processing Record 47 of Set 6 | bilibino
# Processing Record 48 of Set 6 | kenitra
# Processing Record 49 of Set 6 | poltavka
# Processing Record 50 of Set 6 | aswan
# Processing Record 1 of Set 7 | parabel
# Processing Record 2 of Set 7 | anadyr
# Processing Record 3 of Set 7 | thompson
# Processing Record 4 of Set 7 | nouadhibou
# Processing Record 5 of Set 7 | fortuna
# Processing Record 6 of Set 7 | guerrero negro
# Processing Record 7 of Set 7 | greece
# Processing Record 8 of Set 7 | erzin
# Processing Record 9 of Set 7 | wufeng
# Processing Record 10 of Set 7 | moose factory
# Processing Record 11 of Set 7 | keningau
# Processing Record 12 of Set 7 | komsomolskiy
# Processing Record 13 of Set 7 | timra
# Processing Record 14 of Set 7 | cockburn town
# Processing Record 15 of Set 7 | piacabucu
# Processing Record 16 of Set 7 | faya
# Processing Record 17 of Set 7 | saint-francois
# Processing Record 18 of Set 7 | bosaso
# Processing Record 19 of Set 7 | soyo
# Processing Record 20 of Set 7 | mackay
# Processing Record 21 of Set 7 | vallenar
# Processing Record 22 of Set 7 | redcliffe
# Processing Record 23 of Set 7 | the valley
# Processing Record 24 of Set 7 | inuvik
# Processing Record 25 of Set 7 | marsh harbour
# Processing Record 26 of Set 7 | lata
# Processing Record 27 of Set 7 | saint-georges
# Processing Record 28 of Set 7 | lavrentiya
# Processing Record 29 of Set 7 | jibuti
# Processing Record 30 of Set 7 | vila
# Processing Record 31 of Set 7 | samana
# Processing Record 32 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 33 of Set 7 | nova granada
# Processing Record 34 of Set 7 | khash
# Processing Record 35 of Set 7 | larsnes
# Processing Record 36 of Set 7 | obo
# Processing Record 37 of Set 7 | pangai
# Processing Record 38 of Set 7 | northam
# Processing Record 39 of Set 7 | dawlatabad
# Processing Record 40 of Set 7 | bereda
# Processing Record 41 of Set 7 | san nicolas
# Processing Record 42 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 7 | nuevo progreso
# Processing Record 44 of Set 7 | te anau
# Processing Record 45 of Set 7 | mapulot
# Processing Record 46 of Set 7 | alamos
# Processing Record 47 of Set 7 | deputatskiy
# Processing Record 48 of Set 7 | sayat
# Processing Record 49 of Set 7 | tabou
# Processing Record 50 of Set 7 | salinopolis
# Processing Record 1 of Set 8 | merauke
# Processing Record 2 of Set 8 | srednekolymsk
# Processing Record 3 of Set 8 | bailen
# Processing Record 4 of Set 8 | atasu
# Processing Record 5 of Set 8 | qasigiannguit
# Processing Record 6 of Set 8 | dodola
# Processing Record 7 of Set 8 | vardo
# Processing Record 8 of Set 8 | bengkulu
# Processing Record 9 of Set 8 | broken hill
# Processing Record 10 of Set 8 | abrau-dyurso
# Processing Record 11 of Set 8 | umm kaddadah
# Processing Record 12 of Set 8 | monte cristi
# City not found. Skipping...
# Processing Record 13 of Set 8 | port-gentil
# Processing Record 14 of Set 8 | trebon
# Processing Record 15 of Set 8 | yima
# Processing Record 16 of Set 8 | asayita
# City not found. Skipping...
# Processing Record 17 of Set 8 | ust-barguzin
# Processing Record 18 of Set 8 | olinda
# Processing Record 19 of Set 8 | svetlyy
# Processing Record 20 of Set 8 | sangmelima
# Processing Record 21 of Set 8 | port blair
# Processing Record 22 of Set 8 | nikolskoye
# Processing Record 23 of Set 8 | liminangcong
# City not found. Skipping...
# Processing Record 24 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 25 of Set 8 | xifeng
# Processing Record 26 of Set 8 | abu zabad
# Processing Record 27 of Set 8 | poyarkovo
# Processing Record 28 of Set 8 | upata
# Processing Record 29 of Set 8 | poum
# Processing Record 30 of Set 8 | carnarvon
# Processing Record 31 of Set 8 | osoyoos
# Processing Record 32 of Set 8 | coruripe
# Processing Record 33 of Set 8 | porto-vecchio
# Processing Record 34 of Set 8 | awbari
# Processing Record 35 of Set 8 | cap-chat
# Processing Record 36 of Set 8 | hithadhoo
# Processing Record 37 of Set 8 | mount isa
# Processing Record 38 of Set 8 | futog
# Processing Record 39 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 8 | olga
# Processing Record 41 of Set 8 | wanning
# Processing Record 42 of Set 8 | maragogipe
# Processing Record 43 of Set 8 | sumter
# Processing Record 44 of Set 8 | shimoda
# Processing Record 45 of Set 8 | glenwood springs
# Processing Record 46 of Set 8 | bogale
# Processing Record 47 of Set 8 | iberia
# Processing Record 48 of Set 8 | mizpe ramon
# City not found. Skipping...
# Processing Record 49 of Set 8 | chengdu
# Processing Record 50 of Set 8 | buckeye
# Processing Record 1 of Set 9 | bilma
# Processing Record 2 of Set 9 | zyryanka
# Processing Record 3 of Set 9 | polohy
# Processing Record 4 of Set 9 | taltal
# Processing Record 5 of Set 9 | asau
# Processing Record 6 of Set 9 | ingham
# Processing Record 7 of Set 9 | progreso
# Processing Record 8 of Set 9 | bubaque
# Processing Record 9 of Set 9 | adrar
# Processing Record 10 of Set 9 | bonavista
# Processing Record 11 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 12 of Set 9 | gashua
# Processing Record 13 of Set 9 | cochrane
# Processing Record 14 of Set 9 | kichera
# Processing Record 15 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 9 | acarau
# Processing Record 17 of Set 9 | xingyi
# Processing Record 18 of Set 9 | hasaki
# Processing Record 19 of Set 9 | port shepstone
# Processing Record 20 of Set 9 | praia
# Processing Record 21 of Set 9 | coromandel
# Processing Record 22 of Set 9 | chunhuhub
# Processing Record 23 of Set 9 | toktogul
# Processing Record 24 of Set 9 | gold coast
# Processing Record 25 of Set 9 | oksfjord
# Processing Record 26 of Set 9 | marawi
# Processing Record 27 of Set 9 | tiarei
# Processing Record 28 of Set 9 | leshukonskoye
# Processing Record 29 of Set 9 | mogadishu
# Processing Record 30 of Set 9 | apastovo
# Processing Record 31 of Set 9 | san-pedro
# Processing Record 32 of Set 9 | claveria
# Processing Record 33 of Set 9 | kandi
# Processing Record 34 of Set 9 | boguchany
# Processing Record 35 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 9 | gorom-gorom
# Processing Record 37 of Set 9 | naples
# Processing Record 38 of Set 9 | salekhard
# Processing Record 39 of Set 9 | beihai
# Processing Record 40 of Set 9 | mao
# Processing Record 41 of Set 9 | bathsheba
# Processing Record 42 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 9 | raga
# Processing Record 44 of Set 9 | lagoa
# Processing Record 45 of Set 9 | namibe
# Processing Record 46 of Set 9 | casablanca
# Processing Record 47 of Set 9 | grindavik
# Processing Record 48 of Set 9 | ayan
# Processing Record 49 of Set 9 | oriximina
# Processing Record 50 of Set 9 | alyangula
# Processing Record 1 of Set 10 | baykit
# Processing Record 2 of Set 10 | mildura
# Processing Record 3 of Set 10 | isangel
# Processing Record 4 of Set 10 | surab
# Processing Record 5 of Set 10 | victor harbor
# Processing Record 6 of Set 10 | naze
# Processing Record 7 of Set 10 | black river
# Processing Record 8 of Set 10 | jaslo
# Processing Record 9 of Set 10 | mbandaka
# Processing Record 10 of Set 10 | port antonio
# Processing Record 11 of Set 10 | egvekinot
# Processing Record 12 of Set 10 | lotofaga
# Processing Record 13 of Set 10 | pampierstad
# Processing Record 14 of Set 10 | ostrovnoy
# Processing Record 15 of Set 10 | natitingou
# Processing Record 16 of Set 10 | kidodi
# Processing Record 17 of Set 10 | nkowakowa
# Processing Record 18 of Set 10 | mindelo
# Processing Record 19 of Set 10 | itoman
# Processing Record 20 of Set 10 | novoukrainskiy
# Processing Record 21 of Set 10 | khandyga
# Processing Record 22 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 10 | cabedelo
# Processing Record 24 of Set 10 | aklavik
# Processing Record 25 of Set 10 | vao
# Processing Record 26 of Set 10 | neryungri
# Processing Record 27 of Set 10 | kilgore
# Processing Record 28 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 29 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 10 | kastamonu
# Processing Record 31 of Set 10 | yarada
# Processing Record 32 of Set 10 | sao filipe
# Processing Record 33 of Set 10 | comodoro rivadavia
# Processing Record 34 of Set 10 | gat
# Processing Record 35 of Set 10 | yanliang
# Processing Record 36 of Set 10 | washougal
# Processing Record 37 of Set 10 | san rafael
# Processing Record 38 of Set 10 | sioux lookout
# Processing Record 39 of Set 10 | callaway
# Processing Record 40 of Set 10 | ryotsu
# Processing Record 41 of Set 10 | khor
# Processing Record 42 of Set 10 | tshane
# Processing Record 43 of Set 10 | palmaner
# Processing Record 44 of Set 10 | colomi
# Processing Record 45 of Set 10 | birjand
# Processing Record 46 of Set 10 | xichang
# Processing Record 47 of Set 10 | saraipali
# Processing Record 48 of Set 10 | gondanglegi
# Processing Record 49 of Set 10 | warrnambool
# Processing Record 50 of Set 10 | roma
# Processing Record 1 of Set 11 | kousseri
# Processing Record 2 of Set 11 | avera
# Processing Record 3 of Set 11 | andreapol
# Processing Record 4 of Set 11 | hambantota
# Processing Record 5 of Set 11 | thinadhoo
# Processing Record 6 of Set 11 | zacualpan
# Processing Record 7 of Set 11 | abu dhabi
# Processing Record 8 of Set 11 | uthal
# Processing Record 9 of Set 11 | loding
# Processing Record 10 of Set 11 | petropavlovka
# Processing Record 11 of Set 11 | kaitong
# Processing Record 12 of Set 11 | perth
# Processing Record 13 of Set 11 | burica
# City not found. Skipping...
# Processing Record 14 of Set 11 | tucuma
# Processing Record 15 of Set 11 | diplo
# Processing Record 16 of Set 11 | acapulco
# Processing Record 17 of Set 11 | laguna
# Processing Record 18 of Set 11 | oshikango
# Processing Record 19 of Set 11 | kavieng
# Processing Record 20 of Set 11 | khabary
# Processing Record 21 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 22 of Set 11 | tabasco
# Processing Record 23 of Set 11 | la serena
# Processing Record 24 of Set 11 | ust-maya
# Processing Record 25 of Set 11 | yar-sale
# Processing Record 26 of Set 11 | kloulklubed
# Processing Record 27 of Set 11 | aksu
# Processing Record 28 of Set 11 | mizdah
# Processing Record 29 of Set 11 | praia da vitoria
# Processing Record 30 of Set 11 | mbacke
# City not found. Skipping...
# Processing Record 31 of Set 11 | clyde river
# Processing Record 32 of Set 11 | grafton
# Processing Record 33 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 34 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 35 of Set 11 | nanga eboko
# Processing Record 36 of Set 11 | ca mau
# Processing Record 37 of Set 11 | seka
# Processing Record 38 of Set 11 | teguldet
# Processing Record 39 of Set 11 | pangkalanbuun
# Processing Record 40 of Set 11 | mlonggo
# Processing Record 41 of Set 11 | nalut
# Processing Record 42 of Set 11 | gumla
# Processing Record 43 of Set 11 | el guayabito
# Processing Record 44 of Set 11 | hay river
# Processing Record 45 of Set 11 | waldkirch
# Processing Record 46 of Set 11 | banka
# Processing Record 47 of Set 11 | grivenskaya
# Processing Record 48 of Set 11 | walvis bay
# Processing Record 49 of Set 11 | kurtalan
# Processing Record 50 of Set 11 | atar
# Processing Record 1 of Set 12 | dalneye konstantinovo
# City not found. Skipping...
# Processing Record 2 of Set 12 | msowero
# Processing Record 3 of Set 12 | brae
# Processing Record 4 of Set 12 | shakhtinsk
# Processing Record 5 of Set 12 | alice springs
# Processing Record 6 of Set 12 | sayyan
# Processing Record 7 of Set 12 | muros
# Processing Record 8 of Set 12 | chingola
# Processing Record 9 of Set 12 | rio grande
# Processing Record 10 of Set 12 | wageningen
# Processing Record 11 of Set 12 | skibbereen
# Processing Record 12 of Set 12 | westport
# Processing Record 13 of Set 12 | verkhovazhye
# Processing Record 14 of Set 12 | warah
# Processing Record 15 of Set 12 | comillas
# Processing Record 16 of Set 12 | vilyuysk
# Processing Record 17 of Set 12 | balkhash
# Processing Record 18 of Set 12 | shirakamut
# Processing Record 19 of Set 12 | bethanien
# Processing Record 20 of Set 12 | vila velha
# Processing Record 21 of Set 12 | nelson bay
# Processing Record 22 of Set 12 | kysyl-syr
# Processing Record 23 of Set 12 | sur
# Processing Record 24 of Set 12 | dharchula
# Processing Record 25 of Set 12 | hede
# Processing Record 26 of Set 12 | amga
# Processing Record 27 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 12 | seydi
# Processing Record 29 of Set 12 | flinders
# Processing Record 30 of Set 12 | salinas
# Processing Record 31 of Set 12 | njombe
# Processing Record 32 of Set 12 | bassila
# Processing Record 33 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 12 | llangefni
# Processing Record 35 of Set 12 | okhotsk
# Processing Record 36 of Set 12 | roald
# Processing Record 37 of Set 12 | manggar
# Processing Record 38 of Set 12 | gueret
# Processing Record 39 of Set 12 | linfen
# Processing Record 40 of Set 12 | miri
# Processing Record 41 of Set 12 | kautokeino
# Processing Record 42 of Set 12 | jumla
# Processing Record 43 of Set 12 | sagauli
# Processing Record 44 of Set 12 | kachiry
# Processing Record 45 of Set 12 | udachnyy
# Processing Record 46 of Set 12 | emerald
# Processing Record 47 of Set 12 | bourail
# Processing Record 48 of Set 12 | camocim
# Processing Record 49 of Set 12 | juniyah
# City not found. Skipping...
# Processing Record 50 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 1 of Set 13 | redlands
# Processing Record 2 of Set 13 | torrox
# Processing Record 3 of Set 13 | dalby
# Processing Record 4 of Set 13 | mapiripan
# Processing Record 5 of Set 13 | port arthur
# Processing Record 6 of Set 13 | hualmay
# Processing Record 7 of Set 13 | riaba
# City not found. Skipping...
# Processing Record 8 of Set 13 | pokaran
# Processing Record 9 of Set 13 | dzilam gonzalez
# Processing Record 10 of Set 13 | puerto colombia
# Processing Record 11 of Set 13 | kamenka
# Processing Record 12 of Set 13 | takoradi
# Processing Record 13 of Set 13 | nishihara
# Processing Record 14 of Set 13 | devaprayag
# Processing Record 15 of Set 13 | zhezkazgan
# Processing Record 16 of Set 13 | batagay-alyta
# Processing Record 17 of Set 13 | le vauclin
# Processing Record 18 of Set 13 | syracuse
# Processing Record 19 of Set 13 | makariv
# Processing Record 20 of Set 13 | zhigalovo
# Processing Record 21 of Set 13 | oskarshamn
# Processing Record 22 of Set 13 | pimentel
# Processing Record 23 of Set 13 | visby
# Processing Record 24 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 13 | harper
# Processing Record 26 of Set 13 | yanam
# Processing Record 27 of Set 13 | tambura
# Processing Record 28 of Set 13 | sao felix do xingu
# Processing Record 29 of Set 13 | evensk
# Processing Record 30 of Set 13 | mayahi
# Processing Record 31 of Set 13 | ossora
# Processing Record 32 of Set 13 | boddam
# Processing Record 33 of Set 13 | vestmannaeyjar
# Processing Record 34 of Set 13 | ornskoldsvik
# Processing Record 35 of Set 13 | anchorage
# Processing Record 36 of Set 13 | pouembout
# Processing Record 37 of Set 13 | birao
# Processing Record 38 of Set 13 | sinnamary
# Processing Record 39 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 13 | meulaboh
# Processing Record 41 of Set 13 | turukhansk
# Processing Record 42 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 13 | quatre cocos
# Processing Record 44 of Set 13 | chenghai
# Processing Record 45 of Set 13 | samarai
# Processing Record 46 of Set 13 | cedar hill
# Processing Record 47 of Set 13 | maloy
# Processing Record 48 of Set 13 | kungurtug
# Processing Record 49 of Set 13 | altamira
# Processing Record 50 of Set 13 | yurimaguas
# Processing Record 1 of Set 14 | la crosse
# Processing Record 2 of Set 14 | maniitsoq
# Processing Record 3 of Set 14 | osmena
# Processing Record 4 of Set 14 | alcantara
# Processing Record 5 of Set 14 | praya
# Processing Record 6 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 7 of Set 14 | kaitangata
# Processing Record 8 of Set 14 | sembe
# Processing Record 9 of Set 14 | maceio
# Processing Record 10 of Set 14 | mago
# Processing Record 11 of Set 14 | payakumbuh
# Processing Record 12 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 14 | kirensk
# Processing Record 14 of Set 14 | puerto barrios
# Processing Record 15 of Set 14 | breyten
# Processing Record 16 of Set 14 | qafsah
# City not found. Skipping...
# Processing Record 17 of Set 14 | zhangjiakou
# Processing Record 18 of Set 14 | wawa
# Processing Record 19 of Set 14 | umea
# Processing Record 20 of Set 14 | sola
# Processing Record 21 of Set 14 | chumikan
# Processing Record 22 of Set 14 | ankang
# Processing Record 23 of Set 14 | washington
# Processing Record 24 of Set 14 | tazovskiy
# Processing Record 25 of Set 14 | bhubaneswar
# Processing Record 26 of Set 14 | sivas
# Processing Record 27 of Set 14 | chapais
# Processing Record 28 of Set 14 | carutapera
# Processing Record 29 of Set 14 | vizinga
# Processing Record 30 of Set 14 | araouane
# Processing Record 31 of Set 14 | takhtamygda
# Processing Record 32 of Set 14 | barbastro
# Processing Record 33 of Set 14 | yuncheng
# Processing Record 34 of Set 14 | teguise
# Processing Record 35 of Set 14 | chala
# Processing Record 36 of Set 14 | mozelos
# Processing Record 37 of Set 14 | shingu
# Processing Record 38 of Set 14 | susangerd
# Processing Record 39 of Set 14 | yuancheng
# Processing Record 40 of Set 14 | karratha
# Processing Record 41 of Set 14 | tromso
# Processing Record 42 of Set 14 | hanzhong
# Processing Record 43 of Set 14 | quthing
# Processing Record 44 of Set 14 | doka
# Processing Record 45 of Set 14 | port augusta
# Processing Record 46 of Set 14 | bogorodskoye
# Processing Record 47 of Set 14 | bandarbeyla
# Processing Record 48 of Set 14 | capaci
# Processing Record 49 of Set 14 | ust-kuyga
# Processing Record 50 of Set 14 | kilosa
# Processing Record 1 of Set 15 | abomey
# Processing Record 2 of Set 15 | coahuayana
# Processing Record 3 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 4 of Set 15 | mahaicony
# City not found. Skipping...
# Processing Record 5 of Set 15 | ipixuna
# Processing Record 6 of Set 15 | leh
# Processing Record 7 of Set 15 | adet
# Processing Record 8 of Set 15 | wajir
# Processing Record 9 of Set 15 | rockland
# Processing Record 10 of Set 15 | codrington
# Processing Record 11 of Set 15 | zruc nad sazavou
# Processing Record 12 of Set 15 | cap malheureux
# Processing Record 13 of Set 15 | umtata
# Processing Record 14 of Set 15 | cobadin
# Processing Record 15 of Set 15 | klamath falls
# Processing Record 16 of Set 15 | mandalgovi
# Processing Record 17 of Set 15 | garowe
# Processing Record 18 of Set 15 | kargil
# Processing Record 19 of Set 15 | pavda
# City not found. Skipping...
# Processing Record 20 of Set 15 | colomiers
# Processing Record 21 of Set 15 | zhangye
# Processing Record 22 of Set 15 | zwickau
# Processing Record 23 of Set 15 | jonkoping
# Processing Record 24 of Set 15 | toronto
# Processing Record 25 of Set 15 | kemalpasa
# Processing Record 26 of Set 15 | asekeyevo
# Processing Record 27 of Set 15 | mahibadhoo
# Processing Record 28 of Set 15 | ust-kut
# Processing Record 29 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 15 | chum phae
# Processing Record 31 of Set 15 | itanhandu
# Processing Record 32 of Set 15 | yei
# Processing Record 33 of Set 15 | paracuru
# Processing Record 34 of Set 15 | lobito
# Processing Record 35 of Set 15 | komatipoort
# Processing Record 36 of Set 15 | hilotongan
# Processing Record 37 of Set 15 | catuday
# Processing Record 38 of Set 15 | ransang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Tiksi      RU  71.6872  128.8694     -8.57        90          88
# 1       Kodinsk      RU  58.6881   99.1844    -20.54       100          20
# 2  Longyearbyen      SJ  78.2186   15.6401      8.44        78           0
# 3       Iisalmi      FI  63.5592   27.1907     23.02        99         100
# 4   Tuktoyaktuk      CA  69.4541 -133.0374    -27.40        68          20
# 5          Chuy      UY -33.6971  -53.4616     72.25        87         100
# 6        Sabang      ID   5.8933   95.3214     82.47        72          19
# 7        Sorong      ID  -0.8833  131.2500     79.77        81         100
# 8        Lingao      CN  19.9103  109.6859     67.01        84          75
# 9  San Patricio      US  28.0170  -97.5169     69.75        70         100
#
#    Wind Speed Current Description
# 0       16.67     overcast clouds
# 1        1.81          few clouds
# 2       12.66           clear sky
# 3        2.82     overcast clouds
# 4        9.22          few clouds
# 5        9.19     overcast clouds
# 6       16.82          few clouds
# 7        7.27     overcast clouds
# 8       11.92       broken clouds
# 9       24.61     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
